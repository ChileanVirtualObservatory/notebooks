# %% [markdown]
# ## 1.- Importing ROI module

# %%
import sys
sys.path.append('../ACALIB')

from acalib import *
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
# Out:
# /Users/mauricio/anaconda/envs/jupyter/lib/python3.5/site-packages/skimage/filter/__init__.py:6: skimage_deprecation: The `skimage.filter` module has been renamed to `skimage.filters`.  This placeholder module will be removed in v0.13.
#   warn(skimage_deprecation('The `skimage.filter` module has been renamed '

# %% [markdown]
# ## 2.- Reading Data to AContainer

# %%
#Path to fits folder
binpath = '../bindata/'
c = acalib.Container()

#Loading fits to container
c.load_fits(binpath+'.fits')
cube = c.primary

#Creating Spectra Sketcher and Gaussian Segmentation
ss = ri.SpectraSketcher(cube.data)
gs = ri.GaussianSegmentation(prob=0.05, precision=2./100)

#Stacking cube to show emissions
plt.imshow(cube.stack())
plt.show()
cube.shape()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-52c080634c42> in <module>()
#       4
#       5 #Loading fits to container
# ----> 6 c.load_fits(binpath+'ALMA01000740.fits')
#       7 cube = c.primary
#       8
#
# /Users/mauricio/scm/ACALIB/acalib/io/container.py in load_fits(self, path)
#      18
#      19     def load_fits(self,path):
# ---> 20         load_fits_to_cont(path,self)
#      21     def save_fits(self,path):
#      22         save_fits_from_cont(path,self)
#
# /Users/mauricio/scm/ACALIB/acalib/io/fits.py in load_fits_to_cont(filePath, acont)
#     109
#     110 def load_fits_to_cont(filePath,acont):
# --> 111    hdulist = fits.open(filePath)
#     112    for counter,hdu in enumerate(hdulist):
#     113            if isinstance(hdu,fits.PrimaryHDU) or isinstance(hdu,fits.ImageHDU):
#
# /Users/mauricio/anaconda/envs/jupyter/lib/python3.5/site-packages/astropy/io/fits/hdu/hdulist.py in fitsopen(name, mode, memmap, save_backup, cache, **kwargs)
#     137         raise ValueError('Empty filename: %s' % repr(name))
#     138
# --> 139     return HDUList.fromfile(name, mode, memmap, save_backup, cache, **kwargs)
#     140
#     141
#
# /Users/mauricio/anaconda/envs/jupyter/lib/python3.5/site-packages/astropy/io/fits/hdu/hdulist.py in fromfile(cls, fileobj, mode, memmap, save_backup, cache, **kwargs)
#     279
#     280         return cls._readfrom(fileobj=fileobj, mode=mode, memmap=memmap,
# --> 281                              save_backup=save_backup, cache=cache, **kwargs)
#     282
#     283     @classmethod
#
# /Users/mauricio/anaconda/envs/jupyter/lib/python3.5/site-packages/astropy/io/fits/hdu/hdulist.py in _readfrom(cls, fileobj, data, mode, memmap, save_backup, cache, **kwargs)
#     800             if not isinstance(fileobj, _File):
#     801                 # instantiate a FITS file object (ffo)
# --> 802                 ffo = _File(fileobj, mode=mode, memmap=memmap, cache=cache)
#     803             else:
#     804                 ffo = fileobj
#
# /Users/mauricio/anaconda/envs/jupyter/lib/python3.5/site-packages/astropy/io/fits/file.py in __init__(self, fileobj, mode, memmap, clobber, cache)
#     148             self._open_fileobj(fileobj, mode, clobber)
#     149         elif isinstance(fileobj, string_types):
# --> 150             self._open_filename(fileobj, mode, clobber)
#     151         else:
#     152             self._open_filelike(fileobj, mode, clobber)
#
# /Users/mauricio/anaconda/envs/jupyter/lib/python3.5/site-packages/astropy/io/fits/file.py in _open_filename(self, filename, mode, clobber)
#     500             self._file = bz2.BZ2File(self.name, bzip2_mode)
#     501         else:
# --> 502             self._file = fileobj_open(self.name, PYFITS_MODES[mode])
#     503
#     504         # Make certain we're back at the beginning of the file
#
# /Users/mauricio/anaconda/envs/jupyter/lib/python3.5/site-packages/astropy/io/fits/util.py in fileobj_open(filename, mode)
#     387         """
#     388
# --> 389         return open(filename, mode, buffering=0)
#     390 elif six.PY2:
#     391     def fileobj_open(filename, mode):
#
# FileNotFoundError: [Errno 2] No such file or directory: '../bindata/ALMA01000740.fits'

# %% [markdown]
# ## 3.- Cube Spectra Sketch

# %% [markdown]
# Using random samples of pixels, create an sketch of the data cube.

# %%
#Getting frecuencies
xs = cube.shape()[1]
ys = cube.shape()[2]
frecs_len = cube.shape()[0]
frecs = range(frecs_len)

#Creating spectra sketch
spectra,slices = ss.cube_spectra((xs*ys)/100)

#Plotting spectra
plt.bar(frecs,spectra)
plt.show()
slices
# Out:
# [slice(20, 24, None), slice(40, 48, None)]

# %% [markdown]
# ## 4.- Create Slices

# %%
ppslices = []
for i,slic in enumerate(slices):
    fig = plt.figure()
    image = ss.vel_stacking(cube,slic.start,slic.stop)
    
    ax = fig.add_subplot(1,2, 1)
    ax.imshow(image, origin='image')
    print image.shape
    ax = fig.add_subplot(1,256, 2)
    ax.hist(image, bins=256)
    plt.show() 
    ppslices.append(image)
# Out:
# (216, 216)
# (216, 216)
# (216, 216)
# (216, 216)

# %% [markdown]
# ## 5.- Run Segmentation on each slice

# %% [markdown]
# Return Scikit-image RegionProp objects http://scikit-image.org/docs/dev/api/skimage.measure.html#regionprops

# %%
fts_all = []
for image in ppslices:
    fts = gs.gaussian_mix(image)
    fts_all.append(fts)
# Out:
# /usr/lib/python2.7/dist-packages/numpy/core/numeric.py:190: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   a = empty(shape, dtype, order)
