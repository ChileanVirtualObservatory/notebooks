# %%
import astroquery
import astropy
from astropy import units as u
from astropy import coordinates
from astroquery.alma import Alma,utils
from astroquery.skyview import SkyView

# %%
orionkl_coords = coordinates.SkyCoord.from_name('Orion KL')

# %%
orionkl_images = SkyView.get_images(position='Orion KL', survey=['2MASS-K'], pixels=500)
orionkl_images
# Out:
# Downloading http://skyview.gsfc.nasa.gov/tempspace/fits/skv5534213264672.fits [Done]
# [[<astropy.io.fits.hdu.image.PrimaryHDU at 0x7f0ab9f23290>]]

# %%
orionkl = Alma.query_region(coordinate=orionkl_coords, radius=4*u.arcmin, public=False, science=False)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-938b163260ea> in <module>()
# ----> 1 primary_beam_radii = [approximate_primary_beam_sizes(row['Frequency support']) for row in orionkl]
#
# <ipython-input-5-70839bbb290c> in approximate_primary_beam_sizes(frequency_support_str)
#       8
#       9 def approximate_primary_beam_sizes(frequency_support_str):
# ---> 10     freq_ranges = parse_frequency_support(frequency_support_str)
#      11     beam_sizes = [(1.22*fr.mean().to(u.m, u.spectral())/(12*u.m)).to(u.arcsec,
#      12                                                                      u.dimensionless_angles())
#
# <ipython-input-5-70839bbb290c> in parse_frequency_support(frequency_support_str)
#       4                     float(sup.strip('[] ').split("..")[1].split(',')[0].strip(string.letters)))
#       5                    *u.Unit(sup.strip('[] ').split("..")[1].split(',')[0].strip(string.punctuation+string.digits))
# ----> 6                    for sup in supports]
#       7     return u.Quantity(freq_ranges)
#       8
#
# NameError: global name 'string' is not defined

# %%
import aplpy
# %matplotlib inline
print orionkl_images[0]
fig = aplpy.FITSFigure(orionkl_images[0])
fig.show_grayscale(stretch='arcsinh')
ac=orionkl_images[0]
# Out:
# [<astropy.io.fits.hdu.image.PrimaryHDU object at 0x7f0ab9f23290>]
# INFO: Auto-setting vmin to  2.393e+02 [aplpy.core]
# INFO: Auto-setting vmax to  3.155e+03 [aplpy.core]

# %%
ac.
# Out:
# INFO: Auto-setting vmin to  2.393e+02 [aplpy.core]
# INFO: Auto-setting vmax to  3.155e+03 [aplpy.core]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-7df0fbb6e972> in <module>()
# ----> 1 fig.show()
#
# AttributeError: 'FITSFigure' object has no attribute 'show'

# %%
aplpy.
